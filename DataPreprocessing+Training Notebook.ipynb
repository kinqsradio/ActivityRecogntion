# %% [markdown]
# # Introduction
# This repository contains the codebase for an advanced video analysis pipeline that combines the power of multiple state-of-the-art models and methodologies including YOLO V8, ByteTrack, Movenet, and Transformer encoders for high-accuracy activity recognition. The pipeline is trained on the Human Activity Recognition (HAR - Video Dataset)
#
# Reference:
# Datasets: https://www.kaggle.com/datasets/sharjeelmazhar/human-activity-recognition-video-dataset?resource=download-directory

# %%
# !python -V
# Out:
# Python 3.10.13

# %%
# !nvidia-smi
# Out:
# Wed Oct 18 11:44:57 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 522.06       Driver Version: 522.06       CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:07:00.0  On |                  N/A |
# |  0%   42C    P3    22W / 130W |   1413MiB /  8192MiB |     24%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      3240    C+G   ...zpdnekdrzrea0\Spotify.exe    N/A      |
# |    0   N/A  N/A      3276    C+G   ...8wekyb3d8bbwe\GameBar.exe    N/A      |
# |    0   N/A  N/A      6432    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      7956    C+G   ...er_engine\wallpaper32.exe    N/A      |
# |    0   N/A  N/A      8016    C+G   ...logioptionsplus_agent.exe    N/A      |
# |    0   N/A  N/A      8108    C+G   ...n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A      9212    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      9260    C+G   ...icrosoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A     10312    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     11152    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     11260    C+G   ...oft\OneDrive\OneDrive.exe    N/A      |
# |    0   N/A  N/A     13152    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     14164    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     15864    C+G   ...les\NZXT CAM\NZXT CAM.exe    N/A      |
# |    0   N/A  N/A     17920    C+G   ...in7x64\steamwebhelper.exe    N/A      |
# |    0   N/A  N/A     18720    C+G   ...86)\Overwolf\Overwolf.exe    N/A      |
# |    0   N/A  N/A     21932    C+G   ...088.46\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     22072    C+G   ...3.2.2\OverwolfBrowser.exe    N/A      |
# |    0   N/A  N/A     22320    C+G   ...ck\app-4.34.121\slack.exe    N/A      |
# |    0   N/A  N/A     23472    C+G   ...\app-1.0.9019\Discord.exe    N/A      |
# |    0   N/A  N/A     24124    C+G   ...anMyPC\ReminderSystem.exe    N/A      |
# |    0   N/A  N/A     41456    C+G   ...ge\Application\msedge.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Install Dependencies

# %%
# !pip install --upgrade pip
# !pip install tensorflow==2.12.0
# !pip install torch
# !pip install torchvision
# !pip install opencv-python-headless
# !pip install numpy==1.23.5
# !pip install opencv-python

# !pip install imageio
# !pip install opencv-python
# !pip install git+https://github.com/tensorflow/docs
# !pip install git+https://github.com/huggingface/transformers

# !pip install timm
# !pip install scikit-learn 
# !pip install keras

# !pip install matplotlib>=3.3.0
# !pip install opencv-python>=4.6.0
# !pip install pillow>=7.1.2
# !pip install pyyaml>=5.3.1
# !pip install requests>=2.23.0
# !pip install scipy>=1.4.1
# !pip install torch>=1.8.0
# !pip install torchvision>=0.9.0
# !pip install tqdm>=4.64.0

# !pip install pandas>=1.1.4
# !pip install seaborn>=0.11.0

# !pip install psutil
# !pip install py-cpuinfo
# !pip install openpyxl
# !pip install thop>=0.1.1
# !pip install ultralytics

# %% [markdown]
# #  Import Dependencies

# %%
# Standard Library Imports
import torch
import torch.nn as nn
import torchvision.models as models
from torch.nn import TransformerEncoder, TransformerEncoderLayer
import tensorflow as tf
import numpy as np
import random
import gc
gc.enable()

# Third-party Libraries
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
from sklearn.model_selection import train_test_split
from tensorflow import keras

# Custom Module Imports
from train import initialize_dense_model, initialize_lstm_model, initialize_cnn_model, train_model
from datasets import create_datasets, create_cnn_datasets

# Constants or Configuration
from torchvision.models.resnet import ResNet152_Weights
# Out:
# Ultralytics YOLOv8.0.199  Python-3.10.13 torch-2.0.0+cpu CPU (AMD Ryzen 5 5600X 6-Core Processor)
# Setup complete  (12 CPUs, 31.9 GB RAM, 438.6/465.0 GB disk)

# %%
import os
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

SEQUENCE_LENGTH = 50

# Datasets
DATASET_DIR = 'C:/Users/Duc Anh/Desktop/Activity-Recogntion/datasets/Human Activity Recognition - Video Dataset'
CLASSES_LIST = sorted([entry.name for entry in os.scandir(DATASET_DIR) if entry.is_dir()])
print(CLASSES_LIST)

# Setting Up Saving Folder
final = "C:/Users/Duc Anh/Desktop/Activity-Recogntion/final"
if not os.path.exists(final):
    os.makedirs(final)
# %cd "C:/Users/Duc Anh/Desktop/Activity-Recogntion/final"
# Out:
# ['Clapping', 'Meet and Split', 'Sitting', 'Standing Still', 'Walking', 'Walking While Reading Book', 'Walking While Using Phone']
# C:\Users\Duc Anh\Desktop\Activity-Recogntion\final

# %% [markdown]
# # Initialize Model

# %%
# Initialize YOLO model
yolo_model = YOLO('yolov8x.pt')
# yolo_model.to(torch.device("cuda"))

# For spatial features
spatial_resnet = models.resnet152(weights=ResNet152_Weights.IMAGENET1K_V1)
spatial_resnet = nn.Sequential(*list(spatial_resnet.children())[:-1])
spatial_resnet.eval()

# For temporal features
temporal_resnet = models.resnet152(weights=ResNet152_Weights.IMAGENET1K_V1)
temporal_resnet = nn.Sequential(*list(temporal_resnet.children())[:-1])
temporal_resnet.eval()


# Define Transformer Encoders
# fewer attention heads for spatial model
spatial_encoder_layers = TransformerEncoderLayer(d_model=2048, nhead=4)  # fewer attention heads for spatial model
spatial_transformer = TransformerEncoder(spatial_encoder_layers, num_layers=2)

# more attention heads for temporal model
temporal_encoder_layers = TransformerEncoderLayer(d_model=2048, nhead=16)  # more attention heads for temporal model
temporal_transformer = TransformerEncoder(temporal_encoder_layers, num_layers=2)

# %% [markdown]
# # Data Pre-processing

# %%
# Datasets for Dense + LSTM
create_datasets_pth = "C:/Users/Duc Anh/Desktop/Activity-Recogntion/final/create_datasets"
if not os.path.exists(create_datasets_pth):
    os.makedirs(create_datasets_pth)
# %cd "C:/Users/Duc Anh/Desktop/Activity-Recogntion/final/create_datasets"
# Preparing Datasets for Training
dl_features, dl_labels, dl_video_files_paths = create_datasets(yolo_model,
                                                      spatial_resnet,
                                                      spatial_transformer,
                                                      temporal_resnet,
                                                      temporal_transformer,
                                                      DATASET_DIR,
                                                      CLASSES_LIST,
                                                      SEQUENCE_LENGTH,
                                                      NUM_VIDEOS_TO_PROCESS=25)

# Drop any NaN
if np.isnan(dl_features).any():
  # Identify sequences that contain any nan values
  sequences_with_nan = np.any(np.isnan(dl_features), axis=(1, 2))

  # Filter out those sequences
  dl_features = dl_features[~sequences_with_nan]
  dl_labels = dl_labels[~sequences_with_nan]

  print(f"Original number of sequences: {dl_features.shape[0]}")
  print(f"Number of sequences after removal: {dl_labels.shape[0]}")
  print(f'{dl_features.shape}')
  print(f'{dl_labels.shape}')

# Data Augmented, this might be a good testing to scale the datasets for training
from datasets import augment_features
# Generate the augmented data
all_augmented_features = augment_features(dl_features)

# Combine original and all augmented versions
all_features = np.concatenate((dl_features, all_augmented_features), axis=0)

# # Create labels for the augmented data
all_labels = np.tile(dl_labels, (all_features.shape[0] // dl_features.shape[0],))

from tensorflow.keras.utils import to_categorical
dl_one_hot_encoded_labels = to_categorical(all_labels)
dl_features_train, dl_features_test, dl_labels_train, dl_labels_test = train_test_split(all_features, all_labels,
                                                                            test_size = 0.2, shuffle = True,
                                                                            random_state = seed_constant)
# Out:
# C:\Users\Duc Anh\Desktop\Activity-Recogntion\final\create_datasets
# Final data already exists. Loading and skipping further processing...
# Features shape: (160,)
# Labels shape: (160,)
#
# Features shape: (160, 50, 4096)
# Labels shape: (160,)
# Original number of sequences: 158
# Number of sequences after removal: 158
# (158, 50, 4096)
# (158,)

# %%
# Datasets for CNN Model
create_cnn_datasets_pth = "C:/Users/Duc Anh/Desktop/Activity-Recogntion/final/create_cnn_datasets"
if not os.path.exists(create_datasets_pth):
    os.makedirs(create_datasets_pth)
# %cd "C:/Users/Duc Anh/Desktop/Activity-Recogntion/final/create_cnn_datasets"
cnn_features, cnn_labels, cnn_video_files_paths = create_cnn_datasets(DATASET_DIR,
                                                         CLASSES_LIST,
                                                         SEQUENCE_LENGTH,
                                                         NUM_VIDEOS_TO_PROCESS=2)

# Drop any NaN
if np.isnan(cnn_features).any():
  # Identify sequences that contain any nan values
  sequences_with_nan = np.any(np.isnan(cnn_features), axis=(1, 2))

  # Filter out those sequences
  cnn_features = cnn_features[~sequences_with_nan]
  cnn_labels = cnn_labels[~sequences_with_nan]

  print(f"Original number of sequences: {cnn_features.shape[0]}")
  print(f"Number of sequences after removal: {cnn_labels.shape[0]}")
  print(f'{cnn_features.shape}')
  print(f'{cnn_labels.shape}')

from tensorflow.keras.utils import to_categorical
# cnn_one_hot_encoded_labels = to_categorical(cnn_labels)
# Please run this if you want to split the data without Augment!
cnn_features_train, cnn_features_test, cnn_labels_train, cnn_labels_test = train_test_split(cnn_features, cnn_labels,
                                                                            test_size = 0.2, shuffle = True,
                                                                            random_state = seed_constant)

# %%
print('Dense + LSTM')
print(f'Features Train: {dl_features_train.shape}')
print(f'Labels Train: {dl_labels_train.shape}')
print(f'Features Test: {dl_features_test.shape}')
print(f'Labels Test: {dl_labels_test.shape}\n')
# Out:
# Dense + LSTM
# Features Train: (884, 50, 4096)
# Labels Train: (884,)
# Features Test: (222, 50, 4096)
# Labels Test: (222,)

# %%
print('CNN')
print(f'Features Train: {cnn_features_train.shape}')
print(f'Labels Train: {cnn_labels_train.shape}')
print(f'Features Test: {cnn_features_test.shape}')
print(f'Labels Test: {cnn_labels_test.shape}')

# %% [markdown]
# # Model Training

# %%
# %cd "C:/Users/Duc Anh/Desktop/Activity-Recogntion/final/"
# Out:
# C:\Users\Duc Anh\Desktop\Activity-Recogntion\final

# %%
input_shape = (dl_features.shape[1], dl_features.shape[2])
num_classes = len(CLASSES_LIST)

# Dense Model
dense_model = initialize_dense_model(input_shape, num_classes)
dense_model.summary()
# Train model
dense_model_name = 'dense_model'
dense_model = train_model(dense_model_name, 
                          dense_model, 
                          dl_features_train, 
                          dl_labels_train, 
                          batch_size=32, 
                          epochs=1000000000000, 
                          early_stopping_patience=20)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 204800)            0
#
#  dense (Dense)               (None, 512)               104858112
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 105,026,823
# Trainable params: 105,025,031
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 5.4045 - accuracy: 0.2235
# Epoch 1: val_loss improved from inf to 6.15419, saving model to dense_model.h5
# 23/23 [==============================] - 19s 778ms/step - loss: 5.4045 - accuracy: 0.2235 - val_loss: 6.1542 - val_accuracy: 0.5198 - lr: 0.0010
# Epoch 2/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 6.9934 - accuracy: 0.3395
# Epoch 2: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 715ms/step - loss: 6.9934 - accuracy: 0.3395 - val_loss: 6.7742 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 3/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.3919 - accuracy: 0.4116
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 3: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 709ms/step - loss: 7.3919 - accuracy: 0.4116 - val_loss: 6.9729 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 4/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.3889 - accuracy: 0.4611
# Epoch 4: val_loss did not improve from 6.15419
# 23/23 [==============================] - 17s 725ms/step - loss: 7.3889 - accuracy: 0.4611 - val_loss: 6.9612 - val_accuracy: 0.8136 - lr: 2.0000e-04
# Epoch 5/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.2283 - accuracy: 0.5120
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 5: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 713ms/step - loss: 7.2283 - accuracy: 0.5120 - val_loss: 6.8854 - val_accuracy: 0.8305 - lr: 2.0000e-04
# Epoch 6/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.1364 - accuracy: 0.5205
# Epoch 6: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 712ms/step - loss: 7.1364 - accuracy: 0.5205 - val_loss: 6.8988 - val_accuracy: 0.8249 - lr: 4.0000e-05
# Epoch 7/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0948 - accuracy: 0.5530
# Epoch 7: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 7: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 704ms/step - loss: 7.0948 - accuracy: 0.5530 - val_loss: 6.9020 - val_accuracy: 0.8023 - lr: 4.0000e-05
# Epoch 8/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0701 - accuracy: 0.5644
# Epoch 8: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 711ms/step - loss: 7.0701 - accuracy: 0.5644 - val_loss: 6.9186 - val_accuracy: 0.7966 - lr: 8.0000e-06
# Epoch 9/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.1077 - accuracy: 0.5290
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 9: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 717ms/step - loss: 7.1077 - accuracy: 0.5290 - val_loss: 6.9265 - val_accuracy: 0.7797 - lr: 8.0000e-06
# Epoch 10/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0552 - accuracy: 0.5545
# Epoch 10: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 718ms/step - loss: 7.0552 - accuracy: 0.5545 - val_loss: 6.9386 - val_accuracy: 0.7684 - lr: 1.6000e-06
# Epoch 11/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0649 - accuracy: 0.5559
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 11: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 712ms/step - loss: 7.0649 - accuracy: 0.5559 - val_loss: 6.9524 - val_accuracy: 0.7401 - lr: 1.6000e-06
# Epoch 12/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0262 - accuracy: 0.5573
# Epoch 12: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 716ms/step - loss: 7.0262 - accuracy: 0.5573 - val_loss: 6.9602 - val_accuracy: 0.7345 - lr: 1.0000e-06
# Epoch 13/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.1068 - accuracy: 0.5403
# Epoch 13: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 716ms/step - loss: 7.1068 - accuracy: 0.5403 - val_loss: 6.9654 - val_accuracy: 0.7175 - lr: 1.0000e-06
# Epoch 14/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0432 - accuracy: 0.5530
# Epoch 14: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 717ms/step - loss: 7.0432 - accuracy: 0.5530 - val_loss: 6.9729 - val_accuracy: 0.6836 - lr: 1.0000e-06
# Epoch 15/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0354 - accuracy: 0.5488
# Epoch 15: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 711ms/step - loss: 7.0354 - accuracy: 0.5488 - val_loss: 6.9757 - val_accuracy: 0.6949 - lr: 1.0000e-06
# Epoch 16/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 6.9462 - accuracy: 0.5941
# Epoch 16: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 713ms/step - loss: 6.9462 - accuracy: 0.5941 - val_loss: 6.9839 - val_accuracy: 0.6780 - lr: 1.0000e-06
# Epoch 17/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0121 - accuracy: 0.5799
# Epoch 17: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 715ms/step - loss: 7.0121 - accuracy: 0.5799 - val_loss: 6.9840 - val_accuracy: 0.6780 - lr: 1.0000e-06
# Epoch 18/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0534 - accuracy: 0.5233
# Epoch 18: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 713ms/step - loss: 7.0534 - accuracy: 0.5233 - val_loss: 6.9908 - val_accuracy: 0.6780 - lr: 1.0000e-06
# Epoch 19/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0616 - accuracy: 0.5262
# Epoch 19: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 712ms/step - loss: 7.0616 - accuracy: 0.5262 - val_loss: 6.9883 - val_accuracy: 0.6780 - lr: 1.0000e-06
# Epoch 20/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0567 - accuracy: 0.5545
# Epoch 20: val_loss did not improve from 6.15419
# 23/23 [==============================] - 16s 710ms/step - loss: 7.0567 - accuracy: 0.5545 - val_loss: 6.9884 - val_accuracy: 0.6780 - lr: 1.0000e-06
# Epoch 21/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 7.0878 - accuracy: 0.5474Restoring model weights from the end of the best epoch: 1.
#
# Epoch 21: val_loss did not improve from 6.15419
# 23/23 [==============================] - 17s 722ms/step - loss: 7.0878 - accuracy: 0.5474 - val_loss: 6.9921 - val_accuracy: 0.6667 - lr: 1.0000e-06
# Epoch 21: early stopping

# %%
input_shape = (dl_features.shape[1], dl_features.shape[2])
num_classes = len(CLASSES_LIST)

# LSTM MODEL
lstm_model = initialize_lstm_model(input_shape, num_classes)
lstm_model.summary()

# Train model
lstm_model_name = 'lstm_model'
lstm_model = train_model(lstm_model_name, 
                         lstm_model, 
                         dl_features_train, 
                         dl_labels_train,  
                         batch_size=32, 
                         epochs=1000000000000, 
                         early_stopping_patience=20)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 1024)          20975616
#
#  dropout_3 (Dropout)         (None, 50, 1024)          0
#
#  lstm_1 (LSTM)               (None, 50, 512)           3147776
#
#  dropout_4 (Dropout)         (None, 50, 512)           0
#
#  lstm_2 (LSTM)               (None, 256)               787456
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 1024)              263168
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  activation_3 (Activation)   (None, 1024)              0
#
#  dropout_6 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 512)               524800
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_4 (Activation)   (None, 512)               0
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 256)               0
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 25,839,111
# Trainable params: 25,835,527
# Non-trainable params: 3,584
# _________________________________________________________________
# Epoch 1/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 3.9121 - accuracy: 0.1556
# Epoch 1: val_loss improved from inf to 3.30745, saving model to lstm_model.h5
# 23/23 [==============================] - 53s 2s/step - loss: 3.9121 - accuracy: 0.1556 - val_loss: 3.3074 - val_accuracy: 0.2655 - lr: 0.0010
# Epoch 2/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 3.5197 - accuracy: 0.2574
# Epoch 2: val_loss improved from 3.30745 to 3.03496, saving model to lstm_model.h5
# 23/23 [==============================] - 48s 2s/step - loss: 3.5197 - accuracy: 0.2574 - val_loss: 3.0350 - val_accuracy: 0.4237 - lr: 0.0010
# Epoch 3/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 3.0883 - accuracy: 0.4272
# Epoch 3: val_loss improved from 3.03496 to 2.63541, saving model to lstm_model.h5
# 23/23 [==============================] - 48s 2s/step - loss: 3.0883 - accuracy: 0.4272 - val_loss: 2.6354 - val_accuracy: 0.5763 - lr: 0.0010
# Epoch 4/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 2.5585 - accuracy: 0.6096
# Epoch 4: val_loss improved from 2.63541 to 2.27025, saving model to lstm_model.h5
# 23/23 [==============================] - 48s 2s/step - loss: 2.5585 - accuracy: 0.6096 - val_loss: 2.2702 - val_accuracy: 0.7062 - lr: 0.0010
# Epoch 5/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 2.3278 - accuracy: 0.7030
# Epoch 5: val_loss improved from 2.27025 to 2.09039, saving model to lstm_model.h5
# 23/23 [==============================] - 47s 2s/step - loss: 2.3278 - accuracy: 0.7030 - val_loss: 2.0904 - val_accuracy: 0.7458 - lr: 0.0010
# Epoch 6/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 2.1939 - accuracy: 0.7581
# Epoch 6: val_loss improved from 2.09039 to 2.01844, saving model to lstm_model.h5
# 23/23 [==============================] - 48s 2s/step - loss: 2.1939 - accuracy: 0.7581 - val_loss: 2.0184 - val_accuracy: 0.7910 - lr: 0.0010
# Epoch 7/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 2.0485 - accuracy: 0.7921
# Epoch 7: val_loss improved from 2.01844 to 1.92446, saving model to lstm_model.h5
# 23/23 [==============================] - 49s 2s/step - loss: 2.0485 - accuracy: 0.7921 - val_loss: 1.9245 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 8/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 2.0137 - accuracy: 0.7992
# Epoch 8: val_loss improved from 1.92446 to 1.89217, saving model to lstm_model.h5
# 23/23 [==============================] - 48s 2s/step - loss: 2.0137 - accuracy: 0.7992 - val_loss: 1.8922 - val_accuracy: 0.8192 - lr: 0.0010
# Epoch 9/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.9508 - accuracy: 0.8232
# Epoch 9: val_loss did not improve from 1.89217
# 23/23 [==============================] - 47s 2s/step - loss: 1.9508 - accuracy: 0.8232 - val_loss: 1.8943 - val_accuracy: 0.8079 - lr: 0.0010
# Epoch 10/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.9386 - accuracy: 0.8147
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 10: val_loss did not improve from 1.89217
# 23/23 [==============================] - 47s 2s/step - loss: 1.9386 - accuracy: 0.8147 - val_loss: 1.9124 - val_accuracy: 0.7910 - lr: 0.0010
# Epoch 11/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.9299 - accuracy: 0.8175
# Epoch 11: val_loss did not improve from 1.89217
# 23/23 [==============================] - 47s 2s/step - loss: 1.9299 - accuracy: 0.8175 - val_loss: 1.9049 - val_accuracy: 0.7910 - lr: 2.0000e-04
# Epoch 12/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.9291 - accuracy: 0.8289
# Epoch 12: val_loss improved from 1.89217 to 1.88714, saving model to lstm_model.h5
# 23/23 [==============================] - 49s 2s/step - loss: 1.9291 - accuracy: 0.8289 - val_loss: 1.8871 - val_accuracy: 0.7910 - lr: 2.0000e-04
# Epoch 13/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.9114 - accuracy: 0.8105
# Epoch 13: val_loss did not improve from 1.88714
# 23/23 [==============================] - 47s 2s/step - loss: 1.9114 - accuracy: 0.8105 - val_loss: 1.9075 - val_accuracy: 0.7853 - lr: 2.0000e-04
# Epoch 14/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8705 - accuracy: 0.8317
# Epoch 14: val_loss improved from 1.88714 to 1.87668, saving model to lstm_model.h5
# 23/23 [==============================] - 48s 2s/step - loss: 1.8705 - accuracy: 0.8317 - val_loss: 1.8767 - val_accuracy: 0.7966 - lr: 2.0000e-04
# Epoch 15/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8647 - accuracy: 0.8274
# Epoch 15: val_loss improved from 1.87668 to 1.84659, saving model to lstm_model.h5
# 23/23 [==============================] - 47s 2s/step - loss: 1.8647 - accuracy: 0.8274 - val_loss: 1.8466 - val_accuracy: 0.8023 - lr: 2.0000e-04
# Epoch 16/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8621 - accuracy: 0.8246
# Epoch 16: val_loss improved from 1.84659 to 1.84132, saving model to lstm_model.h5
# 23/23 [==============================] - 47s 2s/step - loss: 1.8621 - accuracy: 0.8246 - val_loss: 1.8413 - val_accuracy: 0.7966 - lr: 2.0000e-04
# Epoch 17/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8545 - accuracy: 0.8458
# Epoch 17: val_loss did not improve from 1.84132
# 23/23 [==============================] - 48s 2s/step - loss: 1.8545 - accuracy: 0.8458 - val_loss: 1.9636 - val_accuracy: 0.8136 - lr: 2.0000e-04
# Epoch 18/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8467 - accuracy: 0.8444
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 18: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8467 - accuracy: 0.8444 - val_loss: 1.9190 - val_accuracy: 0.8136 - lr: 2.0000e-04
# Epoch 19/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8356 - accuracy: 0.8402
# Epoch 19: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8356 - accuracy: 0.8402 - val_loss: 1.9111 - val_accuracy: 0.8136 - lr: 4.0000e-05
# Epoch 20/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8329 - accuracy: 0.8472
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 20: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8329 - accuracy: 0.8472 - val_loss: 1.9042 - val_accuracy: 0.8136 - lr: 4.0000e-05
# Epoch 21/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8196 - accuracy: 0.8543
# Epoch 21: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8196 - accuracy: 0.8543 - val_loss: 1.9010 - val_accuracy: 0.8136 - lr: 8.0000e-06
# Epoch 22/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8325 - accuracy: 0.8472
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 22: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8325 - accuracy: 0.8472 - val_loss: 1.8990 - val_accuracy: 0.8136 - lr: 8.0000e-06
# Epoch 23/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8443 - accuracy: 0.8388
# Epoch 23: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8443 - accuracy: 0.8388 - val_loss: 1.8996 - val_accuracy: 0.8136 - lr: 1.6000e-06
# Epoch 24/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8352 - accuracy: 0.8600
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 24: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8352 - accuracy: 0.8600 - val_loss: 1.8993 - val_accuracy: 0.8136 - lr: 1.6000e-06
# Epoch 25/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8399 - accuracy: 0.8487
# Epoch 25: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8399 - accuracy: 0.8487 - val_loss: 1.9006 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 26/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8288 - accuracy: 0.8557
# Epoch 26: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8288 - accuracy: 0.8557 - val_loss: 1.8982 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 27/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8054 - accuracy: 0.8557
# Epoch 27: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8054 - accuracy: 0.8557 - val_loss: 1.8978 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 28/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8464 - accuracy: 0.8472
# Epoch 28: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8464 - accuracy: 0.8472 - val_loss: 1.8970 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 29/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8234 - accuracy: 0.8472
# Epoch 29: val_loss did not improve from 1.84132
# 23/23 [==============================] - 48s 2s/step - loss: 1.8234 - accuracy: 0.8472 - val_loss: 1.8958 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 30/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8601 - accuracy: 0.8430
# Epoch 30: val_loss did not improve from 1.84132
# 23/23 [==============================] - 48s 2s/step - loss: 1.8601 - accuracy: 0.8430 - val_loss: 1.8948 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 31/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8344 - accuracy: 0.8444
# Epoch 31: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8344 - accuracy: 0.8444 - val_loss: 1.8935 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 32/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8322 - accuracy: 0.8600
# Epoch 32: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8322 - accuracy: 0.8600 - val_loss: 1.8940 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 33/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8132 - accuracy: 0.8515
# Epoch 33: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8132 - accuracy: 0.8515 - val_loss: 1.8932 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 34/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8040 - accuracy: 0.8430
# Epoch 34: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8040 - accuracy: 0.8430 - val_loss: 1.8946 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 35/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8300 - accuracy: 0.8529
# Epoch 35: val_loss did not improve from 1.84132
# 23/23 [==============================] - 48s 2s/step - loss: 1.8300 - accuracy: 0.8529 - val_loss: 1.8950 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 36/1000000000000
# 23/23 [==============================] - ETA: 0s - loss: 1.8278 - accuracy: 0.8529Restoring model weights from the end of the best epoch: 16.
#
# Epoch 36: val_loss did not improve from 1.84132
# 23/23 [==============================] - 47s 2s/step - loss: 1.8278 - accuracy: 0.8529 - val_loss: 1.8955 - val_accuracy: 0.8136 - lr: 1.0000e-06
# Epoch 36: early stopping

# %%
input_shape = (cnn_features.shape[1], cnn_features.shape[2], cnn_features.shape[3], cnn_features.shape[4])
num_classes = len(CLASSES_LIST)

# CNN Model
cnn_model = initialize_cnn_model(input_shape, num_classes)
cnn_model.summary()


# Train model
cnn_model_name = 'cnn_model'
cnn_model = train_model(cnn_model_name, 
                         cnn_model, 
                         cnn_features_train, 
                         cnn_labels_train, 
                         batch_size=4, 
                         epochs=1000000000000, 
                         early_stopping_patience=20)
